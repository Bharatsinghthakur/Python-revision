# %%
people = {
    "first": ["Corey", 'Jane', 'John'], 
    "last": ["Schafer", 'Doe', 'Doe'], 
    "email": ["CoreyMSchafer@gmail.com", 'JaneDoe@email.com', 'JohnDoe@email.com']
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df['last'] == 'Doe'
# Out:
# 0    False
# 1     True
# 2     True
# Name: last, dtype: bool

# %%
filt = (df['last'] == 'Doe')

# %%
df[filt]
# Out:
#   first last              email
# 1  Jane  Doe  JaneDoe@email.com
# 2  John  Doe  JohnDoe@email.com

# %%
df[df['last'] == 'Doe'] # another way to do the same thing
# Out:
#   first last              email
# 1  Jane  Doe  JaneDoe@email.com
# 2  John  Doe  JohnDoe@email.com

# %%
df.loc[filt] # this is also giving the same result
# Out:
#   first last              email
# 1  Jane  Doe  JaneDoe@email.com
# 2  John  Doe  JohnDoe@email.com

# %%
# filt = (df['last'] == 'Schafer') | (df['first'] == 'John')

# %%
filt = (df['last'] == 'Doe') & (df['first'] == 'John')

# %%
df.loc(filt)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df.loc(filt)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:766, in _LocationIndexer.__call__(self, axis)
#     763 new_self = type(self)(self.name, self.obj)
#     765 if axis is not None:
# --> 766     axis_int_none = self.obj._get_axis_number(axis)
#     767 else:
#     768     axis_int_none = axis
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:524, in NDFrame._get_axis_number(cls, axis)
#     520     @classmethod
#     521     def _get_axis_number(cls, axis: Axis) -> AxisInt:
#     522         try:
#     523             return cls._AXIS_TO_AXIS_NUMBER[axis]
# --> 524         except KeyError as err:
#     525             raise ValueError(
#     526                 f"No axis named {axis} for object type {cls.__name__}"
#     527             ) from err
#
# TypeError: unhashable type: 'Series'

# %%
df.loc[~filt, 'email']
# Out:
# 1    JaneDoe@email.com
# Name: email, dtype: str

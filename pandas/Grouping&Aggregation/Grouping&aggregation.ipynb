# %%
import pandas as pd

# %%
df = pd.read_csv('../data/survey_results_public.csv')
schema_df = pd.read_csv('../data/survey_results_schema.csv')

# %%
pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',85)

# %%
df.head()
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
# 4           5  I agree  I am a developer by profession  25-34 years old
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
#
#                              RemoteWork  \
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# ...

# %%
df['ConvertedCompYearly'].head(15)
# Out:
# 0          NaN
# 1     285000.0
# 2     250000.0
# 3     156000.0
# 4      23456.0
# 5      96828.0
# 6     135000.0
# 7      80000.0
# 8      64254.0
# 9          NaN
# 10         NaN
# 11     78003.0
# 12     75000.0
# 13    150000.0
# 14    187407.0
# Name: ConvertedCompYearly, dtype: float64

# %%
df['ConvertedCompYearly'].median()
# Out:
# np.float64(74963.0)

# %%
df.median()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df.median()
#
# File c:\Users\bharat singh thakur\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File c:\Users\bharat singh thakur\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:14594, in DataFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   14590         >>> df.median(numeric_only=True)
#   14591         a   1.5
#   14592         dtype: float64
# ...

# %%
df.describe()

# %%
df['ConvertedCompYearly'].count()
# Out:
# np.int64(48019)

# %%
df['SOAccount']
# Out:
# 0        NaN
# 1        Yes
# 2        Yes
# 3        Yes
# 4         No
#         ...
# 89179    Yes
# 89180    Yes
# 89181    NaN
# 89182     No
# 89183    Yes
# Name: SOAccount, Length: 89184, dtype: str

# %%
df['SOAccount'].value_counts()
# Out:
# SOAccount
# Yes                        66282
# No                         14618
# Not sure/can't remember     6952
# Name: count, dtype: int64

# %%
df['OpSysProfessional use'].value_counts()
# Out:
# OpSysProfessional use
# Windows                                                                                                               15943
# MacOS                                                                                                                 12928
# Ubuntu                                                                                                                 5201
# Windows;Windows Subsystem for Linux (WSL)                                                                              3934
# Ubuntu;Windows                                                                                                         2795
#                                                                                                                       ...
# Android;Cygwin;Debian;MacOS;Ubuntu;Windows;Windows Subsystem for Linux (WSL)                                              1
# ...

# %%
schema_df
# Out:
#        qid                 qname  \
# 0    QID16                    S0
# 1    QID12              MetaInfo
# 2   QID310                  Q310
# 3   QID312                  Q120
# 4     QID1                    S1
# 5     QID2            MainBranch
# 6   QID127                   Age
# 7   QID296            Employment
# 8   QID308            RemoteWork
# 9   QID297      CodingActivities
# 10  QID190                    S2
# 11   QID25               EdLevel
# 12  QID276             LearnCode
# 13  QID281       LearnCodeOnline
# 14  QID306  LearnCodeCoursesCert
# 15   QID32             YearsCode
# 16   QID34          YearsCodePro
# 17   QID31               DevType
# 18   QID29               OrgSize
# 19  QID278     PurchaseInfluence
# 20  QID322              TechList
# 21  QID279            BuyNewTool
# 22    QID6               Country
# 23   QID50              Currency
# 24   QID51             CompTotal
# 25   QID61                    S3
# 26  QID233              Language
# ...

# %%
schema_df.columns
# Out:
# Index(['qid', 'qname', 'question', 'force_resp', 'type', 'selector'], dtype='str')

# %%
filt = schema_df['qname'] == 'SOAccount'
schema_df.loc[filt]
# Out:
#        qid      qname                               question force_resp type  \
# 41  QID101  SOAccount  Do you have a Stack Overflow account?      False   MC
#
#    selector
# 41     SAVR

# %%
schema_df.set_index('qname',inplace=True)

# %%
df['OpSysProfessional use'].value_counts()
# Out:
# OpSysProfessional use
# Windows                                                                                                               15943
# MacOS                                                                                                                 12928
# Ubuntu                                                                                                                 5201
# Windows;Windows Subsystem for Linux (WSL)                                                                              3934
# Ubuntu;Windows                                                                                                         2795
#                                                                                                                       ...
# Android;Cygwin;Debian;MacOS;Ubuntu;Windows;Windows Subsystem for Linux (WSL)                                              1
# ...

# %%
# if we want the percentage of these things then we can pass the noramlise = true 
df['OpSysProfessional use'].value_counts(normalize = True)
# Out:
# OpSysProfessional use
# Windows                                                                                                               0.202871
# MacOS                                                                                                                 0.164506
# Ubuntu                                                                                                                0.066181
# Windows;Windows Subsystem for Linux (WSL)                                                                             0.050059
# Ubuntu;Windows                                                                                                        0.035566
#                                                                                                                         ...
# Android;Cygwin;Debian;MacOS;Ubuntu;Windows;Windows Subsystem for Linux (WSL)                                          0.000013
# ...

# %%
# GROUPBY - operation involves some combination of splitting the object , applying the function and Combine the Result

# %%
df['Country'].value_counts()
# Out:
# Country
# United States of America                                18647
# Germany                                                  7328
# India                                                    5625
# United Kingdom of Great Britain and Northern Ireland     5552
# Canada                                                   3507
#                                                         ...
# Saint Kitts and Nevis                                       1
# Marshall Islands                                            1
# Samoa                                                       1
# Central African Republic                                    1
# San Marino                                                  1
# Name: count, Length: 185, dtype: int64

# %%
country_grp = df.groupby('Country')

# %%
country_grp.get_group('India')
# Out:
#        ResponseId     Q120                                         MainBranch  \
# 9              10  I agree                     I am a developer by profession
# 66             67  I agree                     I am a developer by profession
# 78             79  I agree                     I am a developer by profession
# 82             83  I agree                     I am a developer by profession
# 85             86  I agree                     I am a developer by profession
# ...           ...      ...                                                ...
# 89119       89120  I agree                     I am a developer by profession
# 89121       89122  I agree  I am not primarily a developer, but I write co...
# 89164       89165  I agree                     I am a developer by profession
# 89165       89166  I agree                     I am a developer by profession
# 89167       89168  I agree                     I am a developer by profession
#
# ...

# %%
filt = df['Country'] == 'India'
df.loc[filt]['EdLevel'].value_counts()
# Out:
# EdLevel
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          3452
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                        993
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     582
# Some college/university study without earning a degree                                 348
# Primary/elementary school                                                              113
# Something else                                                                          63
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                          54
# Associate degree (A.A., A.S., etc.)                                                     20
# Name: count, dtype: int64

# %%
country_grp['EdLevel'].value_counts().head(50)
# Out:
# Country              EdLevel
# Afghanistan          Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                           20
#                      Something else                                                                         13
#                      Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)      8
#                      Associate degree (A.A., A.S., etc.)                                                     6
#                      Primary/elementary school                                                               6
#                      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                         5
#                      Some college/university study without earning a degree                                  4
#                      Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                          2
# ...

# %%
country_grp['EdLevel'].value_counts().loc['India']
# Out:
# EdLevel
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          3452
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                        993
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     582
# Some college/university study without earning a degree                                 348
# Primary/elementary school                                                              113
# Something else                                                                          63
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                          54
# Associate degree (A.A., A.S., etc.)                                                     20
# Name: count, dtype: int64

# %%
country_grp['CompTotal'].median()
# Out:
# Country
# Afghanistan                                 62333.0
# Albania                                    104850.0
# Algeria                                    540000.0
# Andorra                                    120000.0
# Angola                                    2600000.0
#                                            ...
# Venezuela, Bolivarian Republic of...        14400.0
# Viet Nam                                200000000.0
# Yemen                                        9000.0
# Zambia                                      84000.0
# Zimbabwe                                    12500.0
# Name: CompTotal, Length: 185, dtype: float64

# %%
# for a specific country median salary 
country_grp['CompTotal'].median().loc['India']
# Out:
# np.float64(1450000.0)

# %%
country_grp['CompTotal'].agg(['median','mean'])
# Out:
#                                            median          mean
# Country
# Afghanistan                               62333.0  6.666117e+07
# Albania                                  104850.0  1.185178e+06
# Algeria                                  540000.0  7.836667e+05
# Andorra                                  120000.0  1.562473e+09
# Angola                                  2600000.0  2.600000e+06
# ...                                           ...           ...
# Venezuela, Bolivarian Republic of...      14400.0  2.482463e+04
# Viet Nam                              200000000.0  3.287808e+08
# Yemen                                      9000.0  2.252071e+06
# Zambia                                    84000.0  1.507400e+05
# Zimbabwe                                  12500.0  2.674000e+04
#
# [185 rows x 2 columns]

# %%
country_grp['CompTotal'].agg(['median','mean']).loc['India']
# Out:
# median    1.450000e+06
# mean      1.205815e+07
# Name: India, dtype: float64

# %%
filt = df['Country'] == 'India'
df.loc[filt]['LanguageHaveWorkedWith'].str.contains('Python').sum()
# Out:
# np.int64(2793)

# %%
country_grp['LanguageHaveWorkedWith'] # series groupBy object

# %%
country_grp['LanguageHaveWorkedWith'].apply(lambda x : x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              22
# Albania                                  19
# Algeria                                  35
# Andorra                                   5
# Angola                                    4
#                                        ...
# Venezuela, Bolivarian Republic of...     42
# Viet Nam                                174
# Yemen                                     8
# Zambia                                   11
# Zimbabwe                                 19
# Name: LanguageHaveWorkedWith, Length: 185, dtype: int64

# %%
country_respondent = df['Country'].value_counts()
country_respondent
# Out:
# Country
# United States of America                                18647
# Germany                                                  7328
# India                                                    5625
# United Kingdom of Great Britain and Northern Ireland     5552
# Canada                                                   3507
#                                                         ...
# Saint Kitts and Nevis                                       1
# Marshall Islands                                            1
# Samoa                                                       1
# Central African Republic                                    1
# San Marino                                                  1
# Name: count, Length: 185, dtype: int64

# %%
country_uses_python = country_grp['LanguageHaveWorkedWith'].apply(lambda x : x.str.contains('Python').count())
country_uses_python
# Out:
# Country
# Afghanistan                              64
# Albania                                  60
# Algeria                                  85
# Andorra                                  16
# Angola                                   13
#                                        ...
# Venezuela, Bolivarian Republic of...    106
# Viet Nam                                390
# Yemen                                    20
# Zambia                                   26
# Zimbabwe                                 34
# Name: LanguageHaveWorkedWith, Length: 185, dtype: int64

# %%
python_df = pd.concat([country_respondent,country_uses_python],axis='columns',sort=False)
python_df.rename(columns={'count':'NumRespondents','LanguageHaveWorkedWith':'NumKnowsPython'},inplace=True)

# %%
python_df['PctknowsPython'] = (python_df['NumKnowsPython']/python_df['NumRespondents']) * 100
python_df
# Out:
#                                                     NumRespondents  \
# Country
# United States of America                                     18647
# Germany                                                       7328
# India                                                         5625
# United Kingdom of Great Britain and Northern Ir...            5552
# Canada                                                        3507
# ...                                                            ...
# Saint Kitts and Nevis                                            1
# Marshall Islands                                                 1
# Samoa                                                            1
# Central African Republic                                         1
# San Marino                                                       1
#
#                                                     NumKnowsPython  \
# Country
# United States of America                                     18647
# ...

# %%
python_df.sort_values(by='PctknowsPython',ascending=False,inplace=True)
python_df.describe()
# Out:
#        NumRespondents  NumKnowsPython  PctknowsPython
# count      185.000000      185.000000           185.0
# mean       475.529730      475.529730           100.0
# std       1632.132807     1632.132807             0.0
# min          1.000000        1.000000           100.0
# 25%          9.000000        9.000000           100.0
# 50%         53.000000       53.000000           100.0
# 75%        317.000000      317.000000           100.0
# max      18647.000000    18647.000000           100.0

# %%
python_df.loc['India']
# Out:
# NumRespondents    5625.0
# NumKnowsPython    5625.0
# PctknowsPython     100.0
# Name: India, dtype: float64

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/survey_results_public.csv')
schema_df = pd.read_csv('../data/survey_results_schema.csv')

# %%
pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',85)

# %%
df.head()
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
# 4           5  I agree  I am a developer by profession  25-34 years old
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
#
#                              RemoteWork  \
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# 4                                Remote
#
#                                     CodingActivities  \
# 0                                                NaN
# 1  Hobby;Contribute to open-source projects;Boots...
# 2  Hobby;Professional development or self-paced l...
# 3                                              Hobby
# 4  Hobby;Contribute to open-source projects;Profe...
#
#                                         EdLevel  \
# 0                                           NaN
# 1  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                            LearnCode  \
# 0                                                NaN
# 1  Books / Physical media;Colleague;Friend or fam...
# 2  Books / Physical media;Colleague;On the job tr...
# 3  Colleague;Friend or family member;Other online...
# 4  Books / Physical media;Online Courses or Certi...
#
#                                      LearnCodeOnline  LearnCodeCoursesCert  \
# 0                                                NaN                   NaN
# 1  Formal documentation provided by the owner of ...                 Other
# 2  Formal documentation provided by the owner of ...                   NaN
# 3  Formal documentation provided by the owner of ...                   NaN
# 4  Formal documentation provided by the owner of ...  Other;Codecademy;edX
#
#   YearsCode YearsCodePro                               DevType  \
# 0       NaN          NaN                                   NaN
# 1        18            9  Senior Executive (C-Suite, VP, etc.)
# 2        27           23                   Developer, back-end
# 3        12            7                  Developer, front-end
# 4         6            4                 Developer, full-stack
#
#                     OrgSize                 PurchaseInfluence      TechList  \
# 0                       NaN                               NaN           NaN
# 1          2 to 9 employees  I have a great deal of influence   Investigate
# 2  5,000 to 9,999 employees             I have some influence  Given a list
# 3      100 to 499 employees             I have some influence   Investigate
# 4        20 to 99 employees             I have some influence   Investigate
#
#                                           BuyNewTool  \
# 0                                                NaN
# 1  Start a free trial;Ask developers I know/work ...
# 2  Start a free trial;Ask developers I know/work ...
# 3  Start a free trial;Ask developers I know/work ...
# 4  Start a free trial;Ask developers I know/work ...
#
#                     Country                   Currency  CompTotal  \
# 0                       NaN                        NaN        NaN
# 1  United States of America  USD\tUnited States dollar   285000.0
# 2  United States of America  USD\tUnited States dollar   250000.0
# 3  United States of America  USD\tUnited States dollar   156000.0
# 4               Philippines       PHP\tPhilippine peso  1320000.0
#
#                               LanguageHaveWorkedWith  \
# 0                                                NaN
# 1                         HTML/CSS;JavaScript;Python
# 2                         Bash/Shell (all shells);Go
# 3  Bash/Shell (all shells);HTML/CSS;JavaScript;PH...
# 4                     HTML/CSS;JavaScript;TypeScript
#
#                               LanguageWantToWorkWith  \
# 0                                                NaN
# 1  Bash/Shell (all shells);C#;Dart;Elixir;GDScrip...
# 2                                 Haskell;OCaml;Rust
# 3  Bash/Shell (all shells);HTML/CSS;JavaScript;Ru...
# 4         HTML/CSS;JavaScript;Python;Rust;TypeScript
#
#                       DatabaseHaveWorkedWith  \
# 0                                        NaN
# 1                                   Supabase
# 2                                        NaN
# 3                           PostgreSQL;Redis
# 4  BigQuery;Elasticsearch;MongoDB;PostgreSQL
#
#                             DatabaseWantToWorkWith  \
# 0                                              NaN
# 1              Firebase Realtime Database;Supabase
# 2                                              NaN
# 3                                 PostgreSQL;Redis
# 4  Elasticsearch;MongoDB;PostgreSQL;Redis;Supabase
#
#                               PlatformHaveWorkedWith  \
# 0                                                NaN
# 1           Amazon Web Services (AWS);Netlify;Vercel
# 2  Amazon Web Services (AWS);Google Cloud;OpenSta...
# 3                                  Cloudflare;Heroku
# 4  Amazon Web Services (AWS);Firebase;Heroku;Netl...
#
#                               PlatformWantToWorkWith  \
# 0                                                NaN
# 1                              Fly.io;Netlify;Render
# 2                                                NaN
# 3                                  Cloudflare;Heroku
# 4  Amazon Web Services (AWS);Cloudflare;Digital O...
#
#                          WebframeHaveWorkedWith  \
# 0                                           NaN
# 1                    Next.js;React;Remix;Vue.js
# 2                                           NaN
# 3  Node.js;React;Ruby on Rails;Vue.js;WordPress
# 4   Express;Gatsby;NestJS;Next.js;Node.js;React
#
#                               WebframeWantToWorkWith  \
# 0                                                NaN
# 1               Deno;Elm;Nuxt.js;React;Svelte;Vue.js
# 2                                                NaN
# 3                       Node.js;Ruby on Rails;Vue.js
# 4  Express;NestJS;Next.js;Node.js;React;Remix;Vue.js
#
#         MiscTechHaveWorkedWith                         MiscTechWantToWorkWith  \
# 0                          NaN                                            NaN
# 1  Electron;React Native;Tauri  Capacitor;Electron;Tauri;Uno Platform;Xamarin
# 2                          NaN                                            NaN
# 3                          NaN                                            NaN
# 4                          NaN                                            NaN
#
#                        ToolsTechHaveWorkedWith  \
# 0                                          NaN
# 1  Docker;Kubernetes;npm;Pip;Vite;Webpack;Yarn
# 2             Cargo;Docker;Kubernetes;Make;Nix
# 3               Homebrew;npm;Vite;Webpack;Yarn
# 4                      Docker;npm;Webpack;Yarn
#
#                              ToolsTechWantToWorkWith  \
# 0                                                NaN
# 1  Godot;npm;pnpm;Unity 3D;Unreal Engine;Vite;Web...
# 2                               Cargo;Kubernetes;Nix
# 3                                  Homebrew;npm;Vite
# 4                                    Docker;npm;Yarn
#
#                     NEWCollabToolsHaveWorkedWith NEWCollabToolsWantToWorkWith  \
# 0                                            NaN                          NaN
# 1                         Vim;Visual Studio Code       Vim;Visual Studio Code
# 2                                    Emacs;Helix                  Emacs;Helix
# 3  IntelliJ IDEA;Vim;Visual Studio Code;WebStorm   IntelliJ IDEA;Vim;WebStorm
# 4                         Vim;Visual Studio Code       Vim;Visual Studio Code
#
#                                    OpSysPersonal use  \
# 0                                                NaN
# 1  iOS;iPadOS;MacOS;Windows;Windows Subsystem for...
# 2                            MacOS;Other Linux-based
# 3                                   iOS;iPadOS;MacOS
# 4                            Other (Please Specify):
#
#                              OpSysProfessional use  \
# 0                                              NaN
# 1  MacOS;Windows;Windows Subsystem for Linux (WSL)
# 2                          MacOS;Other Linux-based
# 3                                 iOS;iPadOS;MacOS
# 4                          Other (Please Specify):
#
#                       OfficeStackAsyncHaveWorkedWith  \
# 0                                                NaN
# 1  Asana;Basecamp;GitHub Discussions;Jira;Linear;...
# 2             Markdown File;Stack Overflow for Teams
# 3                                               Jira
# 4                             Confluence;Jira;Notion
#
#             OfficeStackAsyncWantToWorkWith  \
# 0                                      NaN
# 1  GitHub Discussions;Linear;Notion;Trello
# 2                            Markdown File
# 3                                     Jira
# 4                   Confluence;Jira;Notion
#
#                        OfficeStackSyncHaveWorkedWith  \
# 0                                                NaN
# 1  Cisco Webex Teams;Discord;Google Chat;Google M...
# 2                         Microsoft Teams;Slack;Zoom
# 3     Discord;Google Meet;Microsoft Teams;Slack;Zoom
# 4                     Discord;Google Meet;Slack;Zoom
#
#     OfficeStackSyncWantToWorkWith AISearchHaveWorkedWith  \
# 0                             NaN                    NaN
# 1       Discord;Signal;Slack;Zoom                ChatGPT
# 2                      Slack;Zoom                    NaN
# 3  Discord;Google Meet;Slack;Zoom                    NaN
# 4  Discord;Google Meet;Slack;Zoom                ChatGPT
#
#   AISearchWantToWorkWith AIDevHaveWorkedWith AIDevWantToWorkWith  \
# 0                    NaN                 NaN                 NaN
# 1       ChatGPT;Neeva AI      GitHub Copilot      GitHub Copilot
# 2                    NaN                 NaN                 NaN
# 3                    NaN                 NaN                 NaN
# 4                ChatGPT                 NaN                 NaN
#
#                                           NEWSOSites  \
# 0                                                NaN
# 1                      Stack Overflow;Stack Exchange
# 2  Stack Overflow;Stack Exchange;Stack Overflow f...
# 3                      Stack Overflow;Stack Exchange
# 4                      Stack Overflow;Stack Exchange
#
#                        SOVisitFreq SOAccount  \
# 0                              NaN       NaN
# 1            Daily or almost daily       Yes
# 2  A few times per month or weekly       Yes
# 3             A few times per week       Yes
# 4             A few times per week        No
#
#                             SOPartFreq           SOComm  \
# 0                                  NaN              NaN
# 1      A few times per month or weekly  Yes, definitely
# 2  Less than once per month or monthly          Neutral
# 3  Less than once per month or monthly   No, not really
# 4                                  NaN          Neutral
#
#                                                 SOAI                 AISelect  \
# 0                                                NaN                      NaN
# 1  I don't think it's super necessary, but I thin...                      Yes
# 2                                                NaN  No, and I don't plan to
# 3            I'm wearing of Stack Overflow using AI.  No, and I don't plan to
# 4  Using AI to suggest better answer to my questi...                      Yes
#
#            AISent                                              AIAcc  \
# 0             NaN                                                NaN
# 1     Indifferent                             Other (please explain)
# 2             NaN                                                NaN
# 3             NaN                                                NaN
# 4  Very favorable  Increase productivity;Greater efficiency;Speed...
#
#                AIBen                          AIToolInterested in Using  \
# 0                NaN                                                NaN
# 1  Somewhat distrust  Learning about a codebase;Writing code;Debuggi...
# 2                NaN                                                NaN
# 3                NaN                                                NaN
# 4     Somewhat trust  Project planning;Testing code;Committing and r...
#
#                                AIToolCurrently Using  \
# 0                                                NaN
# 1         Writing code;Committing and reviewing code
# 2                                                NaN
# 3                                                NaN
# 4  Learning about a codebase;Writing code;Documen...
#
#   AIToolNot interested in Using AINextVery different  \
# 0                           NaN                  NaN
# 1                           NaN                  NaN
# 2                           NaN                  NaN
# 3                           NaN                  NaN
# 4                           NaN                  NaN
#
#   AINextNeither different nor similar AINextSomewhat similar  \
# 0                                 NaN                    NaN
# 1                                 NaN                    NaN
# 2                                 NaN                    NaN
# 3                                 NaN                    NaN
# 4                                 NaN                    NaN
#
#   AINextVery similar AINextSomewhat different TBranch                  ICorPM  \
# 0                NaN                      NaN     NaN                     NaN
# 1                NaN                      NaN     Yes          People manager
# 2                NaN                      NaN     Yes  Individual contributor
# 3                NaN                      NaN     Yes  Individual contributor
# 4                NaN                      NaN     Yes  Individual contributor
#
#    WorkExp     Knowledge_1                 Knowledge_2     Knowledge_3  \
# 0      NaN             NaN                         NaN             NaN
# 1     10.0  Strongly agree                       Agree  Strongly agree
# 2     23.0  Strongly agree  Neither agree nor disagree           Agree
# 3      7.0  Strongly agree           Strongly disagree  Strongly agree
# 4      6.0           Agree              Strongly agree           Agree
#
#       Knowledge_4                 Knowledge_5                 Knowledge_6  \
# 0             NaN                         NaN                         NaN
# 1           Agree                       Agree                       Agree
# 2           Agree                       Agree                       Agree
# 3  Strongly agree                       Agree  Neither agree nor disagree
# 4           Agree  Neither agree nor disagree                       Agree
#
#       Knowledge_7     Knowledge_8        Frequency_1        Frequency_2  \
# 0             NaN             NaN                NaN                NaN
# 1           Agree  Strongly agree   1-2 times a week   10+ times a week
# 2           Agree           Agree  6-10 times a week  6-10 times a week
# 3           Agree           Agree   1-2 times a week   10+ times a week
# 4  Strongly agree           Agree   1-2 times a week   1-2 times a week
#
#         Frequency_3         TimeSearching        TimeAnswering  \
# 0               NaN                   NaN                  NaN
# 1             Never   15-30 minutes a day  15-30 minutes a day
# 2  3-5 times a week   30-60 minutes a day  30-60 minutes a day
# 3  1-2 times a week   15-30 minutes a day  30-60 minutes a day
# 4  3-5 times a week  60-120 minutes a day  30-60 minutes a day
#
#                                     ProfessionalTech  \
# 0                                                NaN
# 1  DevOps function;Microservices;Automated testin...
# 2  DevOps function;Microservices;Automated testin...
# 3  Automated testing;Continuous integration (CI) ...
# 4  Microservices;Automated testing;Observability ...
#
#                                             Industry           SurveyLength  \
# 0                                                NaN                    NaN
# 1  Information Services, IT, Software Development...  Appropriate in length
# 2  Information Services, IT, Software Development...  Appropriate in length
# 3                                                NaN  Appropriate in length
# 4                                              Other  Appropriate in length
#
#                    SurveyEase  ConvertedCompYearly
# 0                         NaN                  NaN
# 1                        Easy             285000.0
# 2                        Easy             250000.0
# 3                        Easy             156000.0
# 4  Neither easy nor difficult              23456.0

# %%
df.sort_values(by=['Country','CompTotal'],ascending=[True,False],inplace=True)

# %%
df[['Country','CompTotal']].head(100)
# Out:
#            Country    CompTotal
# 88347  Afghanistan  932464379.0
# 1334   Afghanistan     210000.0
# 57361  Afghanistan     200000.0
# 17872  Afghanistan     100000.0
# 36048  Afghanistan      80000.0
# ...            ...          ...
# 64156      Albania          NaN
# 64081      Albania          NaN
# 34270      Albania          NaN
# 19653      Albania          NaN
# 12812      Albania          NaN
#
# [100 rows x 2 columns]

# %%
# N largest salaries

# %%
df['CompTotal'].nlargest(10)
# Out:
# 56322    5.000000e+46
# 18463    1.000000e+21
# 43556    1.000000e+16
# 49553    1.000000e+16
# 35779    1.000000e+15
# 15439    4.567887e+12
# 33078    1.000000e+11
# 19679    2.239672e+10
# 56853    1.980000e+10
# 9175     1.840199e+10
# Name: CompTotal, dtype: float64

# %%
df.nlargest(10,'CompTotal')
# Out:
#        ResponseId     Q120                                         MainBranch  \
# 56322       56323  I agree                     I am a developer by profession
# 18463       18464  I agree                     I am a developer by profession
# 43556       43557  I agree                     I am a developer by profession
# 49553       49554  I agree  I am not primarily a developer, but I write co...
# 35779       35780  I agree                     I am a developer by profession
# 15439       15440  I agree                     I am a developer by profession
# 33078       33079  I agree                     I am a developer by profession
# 19679       19680  I agree                     I am a developer by profession
# 56853       56854  I agree  I am not primarily a developer, but I write co...
# 9175         9176  I agree                     I am a developer by profession
#
#                    Age                                         Employment  \
# 56322  25-34 years old                                Employed, full-time
# 18463  25-34 years old                                Employed, full-time
# 43556  18-24 years old                                Employed, full-time
# 49553  25-34 years old                                Employed, full-time
# 35779  25-34 years old                                I prefer not to say
# 15439  25-34 years old                                Employed, full-time
# 33078  25-34 years old  Independent contractor, freelancer, or self-em...
# 19679  25-34 years old                                Employed, part-time
# 56853  18-24 years old  Employed, full-time;Independent contractor, fr...
# 9175   25-34 years old                                Employed, full-time
#
#       RemoteWork                                   CodingActivities  \
# 56322  In-person  Hobby;Contribute to open-source projects;Boots...
# 18463  In-person                       I don’t code outside of work
# 43556     Remote  Hobby;Contribute to open-source projects;Boots...
# 49553  In-person                       I don’t code outside of work
# 35779        NaN                                                NaN
# 15439  In-person                            School or academic work
# 33078     Remote                            Freelance/contract work
# 19679     Remote  Professional development or self-paced learnin...
# 56853     Remote  Hobby;Contribute to open-source projects;Boots...
# 9175      Remote                                              Hobby
#
#                                                EdLevel  \
# 56322   Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 18463     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 43556     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 49553   Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 35779                                   Something else
# 15439              Associate degree (A.A., A.S., etc.)
# 33078  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 19679   Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 56853  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 9175                         Primary/elementary school
#
#                                                LearnCode  \
# 56322                            Other (please specify):
# 18463  Books / Physical media;Colleague;Friend or fam...
# 43556  Books / Physical media;Online Courses or Certi...
# 49553  Books / Physical media;Colleague;On the job tr...
# 35779  Books / Physical media;Colleague;Friend or fam...
# 15439                            Friend or family member
# 33078  Other online resources (e.g., videos, blogs, f...
# 19679                            Other (please specify):
# 56853  Books / Physical media;Online Courses or Certi...
# 9175                                           Colleague
#
#                                          LearnCodeOnline  \
# 56322                                                NaN
# 18463                                                NaN
# 43556  Formal documentation provided by the owner of ...
# 49553  Formal documentation provided by the owner of ...
# 35779  Formal documentation provided by the owner of ...
# 15439                                                NaN
# 33078  Formal documentation provided by the owner of ...
# 19679                                                NaN
# 56853  Formal documentation provided by the owner of ...
# 9175                                                 NaN
#
#                                 LearnCodeCoursesCert           YearsCode  \
# 56322                                            NaN  More than 50 years
# 18463                                            NaN                  11
# 43556                                    Pluralsight                   8
# 49553                                            NaN                  22
# 35779  Codecademy;Udemy;Pluralsight;Coursera;Udacity                  10
# 15439                                            NaN                   4
# 33078                                            NaN                  11
# 19679                                            NaN                   9
# 56853                 Other;edX;Pluralsight;Coursera                  12
# 9175                                             NaN                 NaN
#
#              YearsCodePro                                        DevType  \
# 56322  More than 50 years                                     Blockchain
# 18463                   8                            Developer, back-end
# 43556                   4  Developer, desktop or enterprise applications
# 49553                   5                    Research & Development role
# 35779                   7                                            NaN
# 15439                   2                       Data or business analyst
# 33078                   8                          Developer, full-stack
# 19679                   3                           Developer Experience
# 56853                   7                          Developer, QA or test
# 9175                  NaN                            Academic researcher
#
#                                                  OrgSize  \
# 56322                           10,000 or more employees
# 18463                                 20 to 99 employees
# 43556                               500 to 999 employees
# 49553                           1,000 to 4,999 employees
# 35779                                 20 to 99 employees
# 15439                                 20 to 99 employees
# 33078                                   2 to 9 employees
# 19679  Just me - I am a freelancer, sole proprietor, ...
# 56853  Just me - I am a freelancer, sole proprietor, ...
# 9175   Just me - I am a freelancer, sole proprietor, ...
#
#                       PurchaseInfluence      TechList  \
# 56322             I have some influence   Investigate
# 18463  I have a great deal of influence   Investigate
# 43556     I have little or no influence           NaN
# 49553             I have some influence   Investigate
# 35779  I have a great deal of influence   Investigate
# 15439  I have a great deal of influence         Other
# 33078  I have a great deal of influence  Given a list
# 19679     I have little or no influence           NaN
# 56853             I have some influence   Investigate
# 9175      I have little or no influence           NaN
#
#                                               BuyNewTool  \
# 56322  Start a free trial;Ask developers I know/work ...
# 18463  Start a free trial;Ask developers I know/work ...
# 43556  Start a free trial;Ask developers I know/work ...
# 49553  Start a free trial;Ask developers I know/work ...
# 35779  Ask developers I know/work with;Visit develope...
# 15439  Read ratings or reviews on third party sites l...
# 33078  Start a free trial;Ask developers I know/work ...
# 19679                            Other (please specify):
# 56853  Ask developers I know/work with;Visit develope...
# 9175                                  Start a free trial
#
#                             Country                         Currency  \
# 56322                       Bahamas  AED United Arab Emirates dirham
# 18463  Iran, Islamic Republic of...                IRR\tIranian rial
# 43556                       Romania                RON\tRomanian leu
# 49553      United States of America        USD\tUnited States dollar
# 35779                        Canada             CAD\tCanadian dollar
# 15439                      Pakistan             KES\tKenyan shilling
# 33078  Iran, Islamic Republic of...                IRR\tIranian rial
# 19679                          Mali      XOF\tWest African CFA franc
# 56853  Iran, Islamic Republic of...                IRR\tIranian rial
# 9175                     Bangladesh            BDT\tBangladeshi taka
#
#           CompTotal                             LanguageHaveWorkedWith  \
# 56322  5.000000e+46                                                Ada
# 18463  1.000000e+21                     Bash/Shell (all shells);Python
# 43556  1.000000e+16  Assembly;Bash/Shell (all shells);C;C#;C++;F#;J...
# 49553  1.000000e+16  Bash/Shell (all shells);C;C++;Fortran;Julia;MA...
# 35779  1.000000e+15  Assembly;Bash/Shell (all shells);C#;C++;Cobol;...
# 15439  4.567887e+12                                               Apex
# 33078  1.000000e+11              HTML/CSS;JavaScript;Kotlin;PHP;Python
# 19679  2.239672e+10                                                Ada
# 56853  1.980000e+10  Bash/Shell (all shells);Go;HTML/CSS;JavaScript...
# 9175   1.840199e+10                                                Ada
#
#                                   LanguageWantToWorkWith  \
# 56322                                                NaN
# 18463       Bash/Shell (all shells);Go;JavaScript;Python
# 43556  Assembly;Bash/Shell (all shells);C;C#;C++;F#;J...
# 49553  Bash/Shell (all shells);C;C++;Fortran;Julia;MA...
# 35779                            HTML/CSS;SQL;TypeScript
# 15439                                                Ada
# 33078         Dart;HTML/CSS;JavaScript;Kotlin;PHP;Python
# 19679                                                Ada
# 56853  Bash/Shell (all shells);Go;HTML/CSS;Python;Rus...
# 9175                                                 NaN
#
#                                   DatabaseHaveWorkedWith  \
# 56322                                                NaN
# 18463                                   PostgreSQL;Redis
# 43556  BigQuery;Cosmos DB;Elasticsearch;MariaDB;Micro...
# 49553                                                NaN
# 35779  Cloud Firestore;Elasticsearch;MariaDB;Microsof...
# 15439                                           BigQuery
# 33078                                       MySQL;SQLite
# 19679                                           BigQuery
# 56853              MariaDB;MySQL;PostgreSQL;Redis;SQLite
# 9175                                            BigQuery
#
#                           DatabaseWantToWorkWith  \
# 56322                                        NaN
# 18463     Elasticsearch;MongoDB;PostgreSQL;Redis
# 43556                                        NaN
# 49553                                        NaN
# 35779                   MariaDB;MySQL;PostgreSQL
# 15439                                        NaN
# 33078                               MySQL;SQLite
# 19679                                   BigQuery
# 56853  Clickhouse;MariaDB;MySQL;PostgreSQL;Redis
# 9175                                         NaN
#
#                                   PlatformHaveWorkedWith  \
# 56322                                                NaN
# 18463                          Amazon Web Services (AWS)
# 43556   Amazon Web Services (AWS);Microsoft Azure;VMware
# 49553                                                NaN
# 35779  Amazon Web Services (AWS);Cloudflare;Digital O...
# 15439  Amazon Web Services (AWS);Cloudflare;Colocatio...
# 33078                                                NaN
# 19679                          Amazon Web Services (AWS)
# 56853  Amazon Web Services (AWS);Cloudflare;Digital O...
# 9175                           Amazon Web Services (AWS)
#
#                                   PlatformWantToWorkWith  \
# 56322                                                NaN
# 18463             Amazon Web Services (AWS);Google Cloud
# 43556                             Microsoft Azure;VMware
# 49553                                                NaN
# 35779                                                NaN
# 15439  Managed Hosting;Oracle Cloud Infrastructure (OCI)
# 33078                                                NaN
# 19679                          Amazon Web Services (AWS)
# 56853        Cloudflare;Hetzner;Microsoft Azure;Scaleway
# 9175                                                 NaN
#
#                                   WebframeHaveWorkedWith  \
# 56322                                                NaN
# 18463                                            FastAPI
# 43556                               ASP.NET;ASP.NET CORE
# 49553                                                NaN
# 35779  Angular;AngularJS;ASP.NET;ASP.NET CORE;Deno;Ex...
# 15439  Angular;AngularJS;ASP.NET;ASP.NET CORE;Blazor;...
# 33078       Express;jQuery;Laravel;Next.js;Node.js;React
# 19679                                            Angular
# 56853         Express;Flask;Next.js;Node.js;React;Vue.js
# 9175                                                 NaN
#
#                              WebframeWantToWorkWith  \
# 56322                                           NaN
# 18463                                       FastAPI
# 43556                                           NaN
# 49553                                           NaN
# 35779                                Angular;NestJS
# 15439                                           NaN
# 33078  Express;jQuery;Laravel;Next.js;Node.js;React
# 19679                                       Angular
# 56853            FastAPI;Flask;Next.js;React;Svelte
# 9175                                            NaN
#
#                     MiscTechHaveWorkedWith  \
# 56322                                  NaN
# 18463                                  NaN
# 43556  .NET (5+) ;GTK;MFC;Opencv;OpenGL;Qt
# 49553                         NumPy;Pandas
# 35779                             Electron
# 15439                                  NaN
# 33078                                   Qt
# 19679                           .NET (5+)
# 56853                                  NaN
# 9175                                   NaN
#
#                                   MiscTechWantToWorkWith  \
# 56322                                                NaN
# 18463                                                NaN
# 43556                           GTK;MFC;Opencv;OpenGL;Qt
# 49553  CUDA;GTK;NumPy;Pandas;Qt;Scikit-Learn;TensorFl...
# 35779                                                NaN
# 15439                                                NaN
# 33078                                                 Qt
# 19679                                         .NET (5+)
# 56853                                                NaN
# 9175                                                 NaN
#
#                                  ToolsTechHaveWorkedWith  \
# 56322                                                NaN
# 18463                                    Composer;Docker
# 43556  Ant;APT;Boost.Test;CMake;cppunit;Dagger;Docker...
# 49553                   CMake;Docker;Make;MSVC;Ninja;Pip
# 35779  Chocolatey;CMake;Composer;Docker;Gradle;npm;We...
# 15439                                             Dagger
# 33078                                                NaN
# 19679                                            Ansible
# 56853            Ansible;APT;Docker;npm;Pip;Webpack;Yarn
# 9175                                                 NaN
#
#                                  ToolsTechWantToWorkWith  \
# 56322                                                NaN
# 18463                                    Composer;Docker
# 43556  Boost.Test;CMake;cppunit;GNU GCC;LLVM's Clang;...
# 49553                        CMake;LLVM's Clang;Make;Pip
# 35779                                         Docker;npm
# 15439                                             Dagger
# 33078                                                NaN
# 19679                                            Ansible
# 56853               Ansible;APT;Docker;Make;Nix;Pip;Yarn
# 9175                                                 NaN
#
#                             NEWCollabToolsHaveWorkedWith  \
# 56322                                                NaN
# 18463                                IPython;PyCharm;Vim
# 43556  Atom;Code::Blocks;Kate;Nano;Notepad++;Qt Creat...
# 49553            Notepad++;Spyder;Vim;Visual Studio Code
# 35779  Android Studio;Atom;Eclipse;Goland;IntelliJ ID...
# 15439                                     Android Studio
# 33078  Android Studio;Atom;Notepad++;PhpStorm;Qt Crea...
# 19679                                     Android Studio
# 56853           Vim;Visual Studio Code;VSCodium;WebStorm
# 9175                                      Android Studio
#
#                             NEWCollabToolsWantToWorkWith  \
# 56322                                                NaN
# 18463                                IPython;PyCharm;Vim
# 43556                      Kate;Qt Creator;Visual Studio
# 49553            Notepad++;Spyder;Vim;Visual Studio Code
# 35779                                 Visual Studio Code
# 15439                                                NaN
# 33078  Android Studio;Atom;Notepad++;PhpStorm;Qt Crea...
# 19679                                     Android Studio
# 56853                    Vim;Visual Studio Code;VSCodium
# 9175                                      Android Studio
#
#                                        OpSysPersonal use  \
# 56322                                                NaN
# 18463                                             Ubuntu
# 43556                              Cygwin;Ubuntu;Windows
# 49553                                     Debian;Windows
# 35779  Android;Ubuntu;Windows;Windows Subsystem for L...
# 15439                                                AIX
# 33078                                            Windows
# 19679                                                AIX
# 56853        Android;Arch;Debian;MacOS;Other Linux-based
# 9175                             Other (Please Specify):
#
#                                    OpSysProfessional use  \
# 56322                                                NaN
# 18463                                             Ubuntu
# 43556                                             Ubuntu
# 49553                                    Red Hat;Windows
# 35779  Android;Red Hat;Ubuntu;Windows;Windows Subsyst...
# 15439                                                NaN
# 33078                                            Windows
# 19679                                                AIX
# 56853                 Debian;iOS;MacOS;Other Linux-based
# 9175                             Other (Please Specify):
#
#                           OfficeStackAsyncHaveWorkedWith  \
# 56322                                                NaN
# 18463                                        Jira;Trello
# 43556                   GitHub Discussions;Markdown File
# 49553                              Markdown File;Redmine
# 35779  Azure Devops;Confluence;Jira;Markdown File;Trello
# 15439                                    Adobe Workfront
# 33078                                                NaN
# 19679                                    Adobe Workfront
# 56853  Clickup;Confluence;Jira;Markdown File;Miro;Mon...
# 9175                                                 NaN
#
#         OfficeStackAsyncWantToWorkWith  \
# 56322                              NaN
# 18463                      Jira;Trello
# 43556               GitHub Discussions
# 49553            Markdown File;Redmine
# 35779                              NaN
# 15439                              NaN
# 33078                              NaN
# 19679                  Adobe Workfront
# 56853  Markdown File;Miro;Notion;Wikis
# 9175                               NaN
#
#                            OfficeStackSyncHaveWorkedWith  \
# 56322                                                NaN
# 18463  Discord;Google Meet;Jitsi;Skype;Slack;Telegram...
# 43556                          IRC;Microsoft Teams;Skype
# 49553                                    Microsoft Teams
# 35779  Cisco Webex Teams;Discord;Google Chat;Google M...
# 15439                                  Cisco Webex Teams
# 33078                                                NaN
# 19679                                  Cisco Webex Teams
# 56853                       Discord;Google Meet;Telegram
# 9175   Coolfire Core;Discord;Google Chat;Google Meet;...
#
#                            OfficeStackSyncWantToWorkWith  \
# 56322                                                NaN
# 18463        Discord;Google Meet;Skype;Telegram;Whatsapp
# 43556                                                NaN
# 49553                                    Microsoft Teams
# 35779                                            Discord
# 15439                                                NaN
# 33078                                                NaN
# 19679                                  Cisco Webex Teams
# 56853                               Google Meet;Telegram
# 9175   Coolfire Core;Discord;Google Chat;Google Meet;...
#
#       AISearchHaveWorkedWith               AISearchWantToWorkWith  \
# 56322                    NaN                                  NaN
# 18463                    NaN                                  NaN
# 43556                    NaN                                  NaN
# 49553           WolframAlpha  ChatGPT;Google Bard AI;WolframAlpha
# 35779                ChatGPT                                  NaN
# 15439                   Andi                                  NaN
# 33078                    NaN                                  NaN
# 19679                   Andi                                 Andi
# 56853        ChatGPT;You.com                                  NaN
# 9175                     NaN                                  NaN
#
#       AIDevHaveWorkedWith AIDevWantToWorkWith  \
# 56322                 NaN                 NaN
# 18463                 NaN                 NaN
# 43556                 NaN                 NaN
# 49553                 NaN                 NaN
# 35779      GitHub Copilot                 NaN
# 15439                 NaN                 NaN
# 33078                 NaN                 NaN
# 19679          Adrenaline          Adrenaline
# 56853                 NaN                 NaN
# 9175                  NaN                 NaN
#
#                                               NEWSOSites  \
# 56322  I have never visited Stack Overflow or the Sta...
# 18463                      Stack Overflow;Stack Exchange
# 43556  Stack Overflow;Stack Exchange;Stack Overflow f...
# 49553                      Stack Overflow;Stack Exchange
# 35779                      Stack Overflow;Stack Exchange
# 15439                      Collectives on Stack Overflow
# 33078  Stack Overflow;Stack Exchange;Stack Overflow f...
# 19679                      Collectives on Stack Overflow
# 56853  Stack Overflow;Stack Exchange;Collectives on S...
# 9175                       Collectives on Stack Overflow
#
#                                SOVisitFreq                SOAccount  \
# 56322                                  NaN  Not sure/can't remember
# 18463               Multiple times per day                      Yes
# 43556  Less than once per month or monthly                      Yes
# 49553               Multiple times per day                      Yes
# 35779      A few times per month or weekly                      Yes
# 15439                Daily or almost daily                      Yes
# 33078               Multiple times per day                      Yes
# 19679  Less than once per month or monthly                      Yes
# 56853                Daily or almost daily                      Yes
# 9175   Less than once per month or monthly                      Yes
#
#                                               SOPartFreq           SOComm  \
# 56322                                                NaN   No, not at all
# 18463                               A few times per week    Yes, somewhat
# 43556                Less than once per month or monthly          Neutral
# 49553                Less than once per month or monthly   No, not really
# 35779                Less than once per month or monthly          Neutral
# 15439  I have never participated in Q&A on Stack Over...          Neutral
# 33078                             Multiple times per day  Yes, definitely
# 19679  I have never participated in Q&A on Stack Over...          Neutral
# 56853                              Daily or almost daily    Yes, somewhat
# 9175   I have never participated in Q&A on Stack Over...   No, not at all
#
#                                                     SOAI  \
# 56322                                                SEX
# 18463                                                NaN
# 43556                                              don't
# 49553  It would be most helpful if the AI could delet...
# 35779                                               none
# 15439                                            Gvmhmko
# 33078                                                NaN
# 19679                                      Profossionnal
# 56853  It's not mature enough yet, Maybe it can be us...
# 9175                                                 NaN
#
#                       AISelect          AISent  \
# 56322  No, and I don't plan to             NaN
# 18463  No, and I don't plan to             NaN
# 43556  No, and I don't plan to             NaN
# 49553  No, and I don't plan to             NaN
# 35779  No, and I don't plan to             NaN
# 15439   No, but I plan to soon     Indifferent
# 33078                      Yes  Very favorable
# 19679                      Yes  Very favorable
# 56853   No, but I plan to soon     Indifferent
# 9175                       Yes  Very favorable
#
#                                          AIAcc                       AIBen  \
# 56322                                      NaN                         NaN
# 18463                                      NaN                         NaN
# 43556                                      NaN                         NaN
# 49553                                      NaN                         NaN
# 35779                                      NaN                         NaN
# 15439                                      NaN  Neither trust nor distrust
# 33078  Increase productivity;Speed up learning              Somewhat trust
# 19679                   Other (please explain)                Highly trust
# 56853                                      NaN             Highly distrust
# 9175                     Increase productivity                Highly trust
#
#                                AIToolInterested in Using  \
# 56322                                                NaN
# 18463                                                NaN
# 43556                                                NaN
# 49553                                                NaN
# 35779                                                NaN
# 15439                                                NaN
# 33078  Learning about a codebase;Project planning;Wri...
# 19679                                                NaN
# 56853                                                NaN
# 9175                                                 NaN
#
#                                    AIToolCurrently Using  \
# 56322                                                NaN
# 18463                                                NaN
# 43556                                                NaN
# 49553                                                NaN
# 35779                                                NaN
# 15439                                                NaN
# 33078  Learning about a codebase;Project planning;Wri...
# 19679                                                NaN
# 56853                                                NaN
# 9175                           Learning about a codebase
#
#       AIToolNot interested in Using  \
# 56322                           NaN
# 18463                           NaN
# 43556                           NaN
# 49553                           NaN
# 35779                           NaN
# 15439                           NaN
# 33078                           NaN
# 19679                           NaN
# 56853                           NaN
# 9175                            NaN
#
#                                     AINextVery different  \
# 56322                                                NaN
# 18463                                                NaN
# 43556                                                NaN
# 49553                                                NaN
# 35779                                                NaN
# 15439                                                NaN
# 33078  Learning about a codebase;Project planning;Wri...
# 19679                                                NaN
# 56853                                                NaN
# 9175                           Learning about a codebase
#
#       AINextNeither different nor similar AINextSomewhat similar  \
# 56322                                 NaN                    NaN
# 18463                                 NaN                    NaN
# 43556                                 NaN                    NaN
# 49553                                 NaN                    NaN
# 35779                                 NaN                    NaN
# 15439                                 NaN                    NaN
# 33078                                 NaN                    NaN
# 19679                                 NaN                    NaN
# 56853                                 NaN                    NaN
# 9175                                  NaN                    NaN
#
#       AINextVery similar AINextSomewhat different TBranch  \
# 56322                NaN                      NaN      No
# 18463                NaN                      NaN     Yes
# 43556                NaN                      NaN      No
# 49553                NaN                      NaN     Yes
# 35779                NaN                      NaN      No
# 15439                NaN                      NaN     Yes
# 33078                NaN                      NaN      No
# 19679                NaN                      NaN     NaN
# 56853                NaN                      NaN     Yes
# 9175                 NaN                      NaN     Yes
#
#                        ICorPM  WorkExp                 Knowledge_1  \
# 56322                     NaN      NaN                         NaN
# 18463          People manager     11.0              Strongly agree
# 43556                     NaN      NaN                         NaN
# 49553  Individual contributor     11.0                       Agree
# 35779                     NaN      NaN                         NaN
# 15439  Individual contributor     16.0  Neither agree nor disagree
# 33078                     NaN      NaN                         NaN
# 19679                     NaN      NaN                         NaN
# 56853  Individual contributor      7.0                    Disagree
# 9175           People manager     20.0           Strongly disagree
#
#                       Knowledge_2                 Knowledge_3  \
# 56322                         NaN                         NaN
# 18463  Neither agree nor disagree                       Agree
# 43556                         NaN                         NaN
# 49553                       Agree                       Agree
# 35779                         NaN                         NaN
# 15439           Strongly disagree  Neither agree nor disagree
# 33078                         NaN                         NaN
# 19679                         NaN                         NaN
# 56853                    Disagree                    Disagree
# 9175                          NaN                         NaN
#
#                       Knowledge_4     Knowledge_5     Knowledge_6  \
# 56322                         NaN             NaN             NaN
# 18463              Strongly agree  Strongly agree  Strongly agree
# 43556                         NaN             NaN             NaN
# 49553  Neither agree nor disagree           Agree           Agree
# 35779                         NaN             NaN             NaN
# 15439                         NaN             NaN             NaN
# 33078                         NaN             NaN             NaN
# 19679                         NaN             NaN             NaN
# 56853  Neither agree nor disagree           Agree        Disagree
# 9175                          NaN             NaN             NaN
#
#                       Knowledge_7     Knowledge_8       Frequency_1  \
# 56322                         NaN             NaN               NaN
# 18463  Neither agree nor disagree  Strongly agree             Never
# 43556                         NaN             NaN               NaN
# 49553  Neither agree nor disagree           Agree  1-2 times a week
# 35779                         NaN             NaN               NaN
# 15439                         NaN             NaN               NaN
# 33078                         NaN             NaN               NaN
# 19679                         NaN             NaN               NaN
# 56853                       Agree           Agree  1-2 times a week
# 9175                          NaN             NaN             Never
#
#              Frequency_2        Frequency_3               TimeSearching  \
# 56322                NaN                NaN                         NaN
# 18463  6-10 times a week                NaN         30-60 minutes a day
# 43556                NaN                NaN                         NaN
# 49553   3-5 times a week   1-2 times a week         30-60 minutes a day
# 35779                NaN                NaN                         NaN
# 15439                NaN  6-10 times a week         30-60 minutes a day
# 33078                NaN                NaN                         NaN
# 19679                NaN                NaN                         NaN
# 56853   1-2 times a week              Never        60-120 minutes a day
# 9175               Never                NaN  Less than 15 minutes a day
#
#                     TimeAnswering  \
# 56322                         NaN
# 18463         30-60 minutes a day
# 43556                         NaN
# 49553         30-60 minutes a day
# 35779                         NaN
# 15439      Over 120 minutes a day
# 33078                         NaN
# 19679                         NaN
# 56853         15-30 minutes a day
# 9175   Less than 15 minutes a day
#
#                                         ProfessionalTech  \
# 56322                                                NaN
# 18463  Microservices;Continuous integration (CI) and ...
# 43556                                                NaN
# 49553  DevOps function;Automated testing;Continuous i...
# 35779                                                NaN
# 15439  Continuous integration (CI) and (more often) c...
# 33078                                                NaN
# 19679                                                NaN
# 56853  Automated testing;Continuous integration (CI) ...
# 9175                              Innersource initiative
#
#                                                 Industry  \
# 56322                                                NaN
# 18463                                                NaN
# 43556                                                NaN
# 49553  Information Services, IT, Software Development...
# 35779                                                NaN
# 15439                                                NaN
# 33078                                                NaN
# 19679                                                NaN
# 56853  Information Services, IT, Software Development...
# 9175                                                 NaN
#
#                 SurveyLength                  SurveyEase  ConvertedCompYearly
# 56322               Too long                   Difficult                  NaN
# 18463  Appropriate in length                        Easy                  NaN
# 43556               Too long  Neither easy nor difficult                  NaN
# 49553  Appropriate in length                        Easy                  NaN
# 35779               Too long                        Easy                  NaN
# 15439  Appropriate in length                         NaN                  NaN
# 33078  Appropriate in length                        Easy            2362249.0
# 19679              Too short                        Easy           36573181.0
# 56853  Appropriate in length  Neither easy nor difficult             467725.0
# 9175               Too short                         NaN                  NaN

# %%
df.nsmallest(10,'CompTotal')
# Out:
#        ResponseId     Q120                                         MainBranch  \
# 67793       67794  I agree                     I am a developer by profession
# 59005       59006  I agree                     I am a developer by profession
# 53787       53788  I agree                     I am a developer by profession
# 4350         4351  I agree                     I am a developer by profession
# 74557       74558  I agree  I am not primarily a developer, but I write co...
# 51706       51707  I agree                     I am a developer by profession
# 8983         8984  I agree  I am not primarily a developer, but I write co...
# 88949       88950  I agree  I am not primarily a developer, but I write co...
# 83554       83555  I agree                     I am a developer by profession
# 10730       10731  I agree  I am not primarily a developer, but I write co...
#
#                      Age                                         Employment  \
# 67793    18-24 years old  Independent contractor, freelancer, or self-em...
# 59005    35-44 years old                                Employed, full-time
# 53787    35-44 years old  Independent contractor, freelancer, or self-em...
# 4350     18-24 years old  Independent contractor, freelancer, or self-em...
# 74557  Prefer not to say                                I prefer not to say
# 51706    25-34 years old  Independent contractor, freelancer, or self-em...
# 8983   65 years or older  Independent contractor, freelancer, or self-em...
# 88949  65 years or older                                            Retired
# 83554    25-34 years old  Independent contractor, freelancer, or self-em...
# 10730    18-24 years old                                Employed, full-time
#
#                                  RemoteWork  \
# 67793                                Remote
# 59005  Hybrid (some remote, some in-person)
# 53787  Hybrid (some remote, some in-person)
# 4350                                 Remote
# 74557                                   NaN
# 51706                                Remote
# 8983                                 Remote
# 88949                                   NaN
# 83554                                Remote
# 10730  Hybrid (some remote, some in-person)
#
#                                         CodingActivities  \
# 67793                            Other (please specify):
# 59005                       I don’t code outside of work
# 53787  Hobby;Contribute to open-source projects;Boots...
# 4350   Hobby;Professional development or self-paced l...
# 74557                                                NaN
# 51706  Hobby;Contribute to open-source projects;Boots...
# 8983                             School or academic work
# 88949                                                NaN
# 83554  Professional development or self-paced learnin...
# 10730                                              Hobby
#
#                                                  EdLevel  \
# 67793                                     Something else
# 59005       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 53787       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4350   Secondary school (e.g. American high school, G...
# 74557    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 51706                                     Something else
# 8983     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 88949  Secondary school (e.g. American high school, G...
# 83554       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 10730       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                LearnCode  \
# 67793                            Other (please specify):
# 59005  Books / Physical media;On the job training;Sch...
# 53787  Colleague;Friend or family member;Coding Bootc...
# 4350   Books / Physical media;Online Courses or Certi...
# 74557  Books / Physical media;Online Courses or Certi...
# 51706  Books / Physical media;Other online resources ...
# 8983   Books / Physical media;Online Courses or Certi...
# 88949  Books / Physical media;Colleague;On the job tr...
# 83554  Friend or family member;Other online resources...
# 10730                    Online Courses or Certification
#
#                                          LearnCodeOnline  \
# 67793                                                NaN
# 59005                                                NaN
# 53787                                                NaN
# 4350   Formal documentation provided by the owner of ...
# 74557                                                NaN
# 51706  Formal documentation provided by the owner of ...
# 8983                                                 NaN
# 88949                                                NaN
# 83554  Formal documentation provided by the owner of ...
# 10730                                                NaN
#
#          LearnCodeCoursesCert           YearsCode        YearsCodePro  \
# 67793                     NaN  More than 50 years  More than 50 years
# 59005                     NaN                  30                  16
# 53787                     NaN                  23                  19
# 4350                      NaN                   1    Less than 1 year
# 74557                     NaN                  35                  30
# 51706                     NaN                  22                  16
# 8983   Udemy;Coursera;Udacity                  43                  43
# 88949                     NaN                  46                  46
# 83554                     NaN                   4                   4
# 10730             Other;Udemy                   3                 NaN
#
#                                              DevType  \
# 67793                        Other (please specify):
# 59005  Developer, desktop or enterprise applications
# 53787                                Product manager
# 4350                           Developer, full-stack
# 74557                                            NaN
# 51706                    Research & Development role
# 8983                             Academic researcher
# 88949                                            NaN
# 83554                          Developer, full-stack
# 10730                                        Student
#
#                                                  OrgSize  \
# 67793                                       I don’t know
# 59005                           5,000 to 9,999 employees
# 53787                                   2 to 9 employees
# 4350   Just me - I am a freelancer, sole proprietor, ...
# 74557                                       I don’t know
# 51706  Just me - I am a freelancer, sole proprietor, ...
# 8983   Just me - I am a freelancer, sole proprietor, ...
# 88949  Just me - I am a freelancer, sole proprietor, ...
# 83554                                   2 to 9 employees
# 10730                                   2 to 9 employees
#
#                       PurchaseInfluence      TechList  \
# 67793  I have a great deal of influence         Other
# 59005     I have little or no influence           NaN
# 53787  I have a great deal of influence   Investigate
# 4350   I have a great deal of influence   Investigate
# 74557             I have some influence  Given a list
# 51706  I have a great deal of influence   Investigate
# 8983   I have a great deal of influence   Investigate
# 88949  I have a great deal of influence   Investigate
# 83554  I have a great deal of influence   Investigate
# 10730     I have little or no influence           NaN
#
#                                               BuyNewTool      Country  \
# 67793                            Other (please specify):  Afghanistan
# 59005  Start a free trial;Ask developers I know/work ...  Afghanistan
# 53787  Start a free trial;Ask developers I know/work ...    Argentina
# 4350   Ask developers I know/work with;Visit develope...    Argentina
# 74557  Visit developer communities like Stack Overflo...    Australia
# 51706  Start a free trial;Ask developers I know/work ...    Australia
# 8983          Start a free trial;Other (please specify):    Australia
# 88949  Start a free trial;Ask developers I know/work ...    Australia
# 83554  Start a free trial;Ask developers I know/work ...    Australia
# 10730  Start a free trial;Ask developers I know/work ...   Bangladesh
#
#                                            Currency  CompTotal  \
# 67793  BAM\tBosnia and Herzegovina convertible mark        0.0
# 59005                         AZN\tAzerbaijan manat        0.0
# 53787                     USD\tUnited States dollar        0.0
# 4350                            ARS\tArgentine peso        0.0
# 74557                        AUD\tAustralian dollar        0.0
# 51706                        AUD\tAustralian dollar        0.0
# 8983                         AUD\tAustralian dollar        0.0
# 88949                        AUD\tAustralian dollar        0.0
# 83554                        AUD\tAustralian dollar        0.0
# 10730                     USD\tUnited States dollar        0.0
#
#                                   LanguageHaveWorkedWith  \
# 67793                                                NaN
# 59005                C;C#;C++;Java;PowerShell;Python;VBA
# 53787  Bash/Shell (all shells);C;C++;PHP;Python;SQL;T...
# 4350                           JavaScript;SQL;TypeScript
# 74557                              C;Fortran;Perl;Python
# 51706  Assembly;Bash/Shell (all shells);C;C++;Go;HTML...
# 8983                                                   R
# 88949                            C++;Delphi;Java;PHP;SQL
# 83554                            HTML/CSS;SQL;TypeScript
# 10730   C;C#;C++;HTML/CSS;Java;JavaScript;PHP;Python;SQL
#
#                                   LanguageWantToWorkWith  \
# 67793                                                NaN
# 59005                       C#;C++;PowerShell;Python;VBA
# 53787  Bash/Shell (all shells);C;C++;Python;Rust;SQL;...
# 4350                           JavaScript;SQL;TypeScript
# 74557                                              Julia
# 51706   Assembly;C;OCaml;Python;Ruby;Rust;TypeScript;Zig
# 8983                                                   R
# 88949                                         Delphi;SQL
# 83554                            HTML/CSS;SQL;TypeScript
# 10730                                                NaN
#
#                             DatabaseHaveWorkedWith DatabaseWantToWorkWith  \
# 67793                                          NaN                    NaN
# 59005                         Microsoft SQL Server   Microsoft SQL Server
# 53787                          Dynamodb;PostgreSQL             PostgreSQL
# 4350   MariaDB;Microsoft SQL Server;MySQL;Supabase   Microsoft SQL Server
# 74557                         MariaDB;MySQL;SQLite                    NaN
# 51706        Elasticsearch;PostgreSQL;Redis;SQLite                    NaN
# 8983                                        SQLite        BigQuery;SQLite
# 88949                                          NaN                    NaN
# 83554                     Cloud Firestore;Supabase               Supabase
# 10730          Microsoft SQL Server;MongoDB;Oracle                    NaN
#
#                                   PlatformHaveWorkedWith  \
# 67793                                                NaN
# 59005                                                NaN
# 53787                          Amazon Web Services (AWS)
# 4350                             Firebase;Netlify;Vercel
# 74557                          Amazon Web Services (AWS)
# 51706     Amazon Web Services (AWS);Cloudflare;OVH;Vultr
# 8983                                                 NaN
# 88949                                                NaN
# 83554    Cloudflare;Firebase;Google Cloud;Netlify;Vercel
# 10730  Amazon Web Services (AWS);Cloudflare;Firebase;...
#
#           PlatformWantToWorkWith              WebframeHaveWorkedWith  \
# 67793                        NaN                                 NaN
# 59005                        NaN                                 NaN
# 53787  Amazon Web Services (AWS)              Angular;Django;Node.js
# 4350                      Vercel        NestJS;Next.js;Node.js;React
# 74557                        NaN                                 NaN
# 51706                        OVH  Django;Node.js;React;Ruby on Rails
# 8983                         NaN                                 NaN
# 88949                        NaN                                 NaN
# 83554          Cloudflare;Vercel                       Next.js;React
# 10730                        NaN           AngularJS;ASP.NET;Node.js
#
#                                   WebframeWantToWorkWith  \
# 67793                                                NaN
# 59005                                                NaN
# 53787                                     Angular;Django
# 4350   AngularJS;ASP.NET;ASP.NET CORE;NestJS;Next.js;...
# 74557                                                NaN
# 51706                                                NaN
# 8983                                                 NaN
# 88949                                                NaN
# 83554                                      Next.js;React
# 10730                                    Next.js;Node.js
#
#                           MiscTechHaveWorkedWith  \
# 67793                                        NaN
# 59005  .NET (5+) ;.NET Framework (1.0 - 4.8);MFC
# 53787                  Apache Spark;NumPy;Pandas
# 4350                  .NET Framework (1.0 - 4.8)
# 74557                               Scikit-Learn
# 51706                                        NaN
# 8983                                         NaN
# 88949                                        NaN
# 83554                                        NaN
# 10730                                    SwiftUI
#
#                           MiscTechWantToWorkWith  \
# 67793                                        NaN
# 59005  .NET (5+) ;.NET Framework (1.0 - 4.8);MFC
# 53787                               NumPy;Pandas
# 4350           .NET (5+) ;Electron;Flutter;Tauri
# 74557                                        NaN
# 51706                                        NaN
# 8983                                         NaN
# 88949                                        NaN
# 83554                                        NaN
# 10730                                        NaN
#
#                                  ToolsTechHaveWorkedWith  \
# 67793                                                NaN
# 59005          MSBuild;MSVC;NuGet;Visual Studio Solution
# 53787                                    Docker;Homebrew
# 4350                        Gradle;npm;pnpm;Vite;Webpack
# 74557                                                NaN
# 51706  APT;Cargo;CMake;Docker;GNU GCC;Google Test;Hom...
# 8983                                                 NaN
# 88949                                                NaN
# 83554                                                npm
# 10730  Google Test;Unity 3D;Unreal Engine;Visual Stud...
#
#                          ToolsTechWantToWorkWith  \
# 67793                                        NaN
# 59005  MSBuild;MSVC;NuGet;Visual Studio Solution
# 53787                                        NaN
# 4350                          npm;pnpm;Vite;Yarn
# 74557                                        NaN
# 51706                          LLVM's Clang;Make
# 8983                                         NaN
# 88949                                        NaN
# 83554                                        npm
# 10730                                        NaN
#
#                             NEWCollabToolsHaveWorkedWith  \
# 67793                                                NaN
# 59005  IntelliJ IDEA;Notepad++;Rider;Sublime Text;Vis...
# 53787   PhpStorm;PyCharm;Sublime Text;Visual Studio Code
# 4350     Android Studio;Visual Studio;Visual Studio Code
# 74557           BBEdit;Jupyter Notebook/JupyterLab;Xcode
# 51706   Emacs;Vim;Visual Studio;Visual Studio Code;Xcode
# 8983                                      Android Studio
# 88949                                                NaN
# 83554                                 Visual Studio Code
# 10730  Code::Blocks;Jupyter Notebook/JupyterLab;Netbe...
#
#                      NEWCollabToolsWantToWorkWith  \
# 67793                                         NaN
# 59005  Notepad++;Visual Studio;Visual Studio Code
# 53787                                         NaN
# 4350                           Visual Studio Code
# 74557                                         NaN
# 51706                      Vim;Visual Studio Code
# 8983                               Android Studio
# 88949                                         NaN
# 83554                          Visual Studio Code
# 10730                                         NaN
#
#                                        OpSysPersonal use  \
# 67793                                                NaN
# 59005                                            Windows
# 53787                                              MacOS
# 4350                                             Windows
# 74557                               BSD;iOS;MacOS;Ubuntu
# 51706  BSD;Debian;iOS;iPadOS;MacOS;Windows;Windows Su...
# 8983                    Android;iOS;iPadOS;MacOS;Windows
# 88949                                            Windows
# 83554                                            Windows
# 10730                                            Windows
#
#                                    OpSysProfessional use  \
# 67793                                                NaN
# 59005                                            Windows
# 53787                                                NaN
# 4350     Android;Debian;Other Linux-based;Ubuntu;Windows
# 74557                                                NaN
# 51706  Debian;MacOS;Windows;Windows Subsystem for Lin...
# 8983                    Android;iOS;iPadOS;MacOS;Windows
# 88949                                            Windows
# 83554                                            Windows
# 10730                                                NaN
#
#                OfficeStackAsyncHaveWorkedWith OfficeStackAsyncWantToWorkWith  \
# 67793                                     NaN                            NaN
# 59005                  Confluence;Jira;Trello                            NaN
# 53787                                  Notion                         Notion
# 4350                                     Jira                            NaN
# 74557                      GitHub Discussions                            NaN
# 51706  GitHub Discussions;Markdown File;Wikis                  Markdown File
# 8983                                      NaN                            NaN
# 88949                                     NaN                            NaN
# 83554                                  Notion                            NaN
# 10730                                  Tettra                            NaN
#
#                            OfficeStackSyncHaveWorkedWith  \
# 67793                                                NaN
# 59005                                    Microsoft Teams
# 53787                                           Whatsapp
# 4350           Google Meet;Microsoft Teams;Whatsapp;Zoom
# 74557       Google Chat;Google Meet;Microsoft Teams;Zoom
# 51706           Discord;IRC;Matrix;Mattermost;Slack;Zoom
# 8983                                                Zoom
# 88949                                               Zoom
# 83554                          Google Meet;Whatsapp;Zoom
# 10730  Cisco Webex Teams;Discord;Google Chat;Google M...
#
#       OfficeStackSyncWantToWorkWith          AISearchHaveWorkedWith  \
# 67793                           NaN                             NaN
# 59005                           NaN                             NaN
# 53787                           NaN                         ChatGPT
# 4350                            NaN                         ChatGPT
# 74557                           NaN                         ChatGPT
# 51706            Discord;IRC;Matrix                         ChatGPT
# 8983                           Zoom                 Bing AI;ChatGPT
# 88949                           NaN                             NaN
# 83554                   Google Meet                         ChatGPT
# 10730                           NaN  Bing AI;ChatGPT;Google Bard AI
#
#       AISearchWantToWorkWith               AIDevHaveWorkedWith  \
# 67793                    NaN                               NaN
# 59005                    NaN                               NaN
# 53787                    NaN  AWS CodeWhisperer;GitHub Copilot
# 4350                     NaN                               NaN
# 74557                    NaN                               NaN
# 51706                ChatGPT                    GitHub Copilot
# 8983         Bing AI;ChatGPT                               NaN
# 88949                    NaN                               NaN
# 83554                ChatGPT  AWS CodeWhisperer;GitHub Copilot
# 10730                    NaN                               NaN
#
#       AIDevWantToWorkWith                                         NEWSOSites  \
# 67793                 NaN                      Collectives on Stack Overflow
# 59005                 NaN                      Stack Overflow;Stack Exchange
# 53787                 NaN                      Stack Overflow;Stack Exchange
# 4350                  NaN                                     Stack Overflow
# 74557                 NaN                      Stack Overflow;Stack Exchange
# 51706      GitHub Copilot                      Stack Overflow;Stack Exchange
# 8983                  NaN  Stack Overflow;Stack Overflow for Teams (priva...
# 88949                 NaN  Stack Overflow;Stack Exchange;Collectives on S...
# 83554                 NaN                      Stack Overflow;Stack Exchange
# 10730                 NaN  Stack Overflow;Stack Exchange;Stack Overflow f...
#
#                            SOVisitFreq                SOAccount  \
# 67793           Multiple times per day  Not sure/can't remember
# 59005             A few times per week                       No
# 53787           Multiple times per day                      Yes
# 4350              A few times per week                      Yes
# 74557  A few times per month or weekly                      Yes
# 51706  A few times per month or weekly                      Yes
# 8983   A few times per month or weekly                      Yes
# 88949  A few times per month or weekly                      Yes
# 83554  A few times per month or weekly                       No
# 10730             A few times per week                      Yes
#
#                                               SOPartFreq           SOComm  \
# 67793                                                NaN         Not sure
# 59005                                                NaN   No, not at all
# 53787                    A few times per month or weekly    Yes, somewhat
# 4350   I have never participated in Q&A on Stack Over...   No, not really
# 74557                Less than once per month or monthly          Neutral
# 51706                    A few times per month or weekly    Yes, somewhat
# 8983                 Less than once per month or monthly   No, not really
# 88949  I have never participated in Q&A on Stack Over...    Yes, somewhat
# 83554                                                NaN   No, not really
# 10730  I have never participated in Q&A on Stack Over...  Yes, definitely
#
#                                                     SOAI  \
# 67793  Why are the admins at StackOverflow so cocky? ...
# 59005                                                NaN
# 53787  I think you should label all AI generated cont...
# 4350                                                 NaN
# 74557                                       worth trying
# 51706                                                NaN
# 8983                                    Free textbpropts
# 88949                                                NaN
# 83554  I'm not sure - I don't go to stack overflow mu...
# 10730  I believe that incorporating AI tools to impro...
#
#                       AISelect          AISent  \
# 67793                      Yes          Unsure
# 59005  No, and I don't plan to             NaN
# 53787                      Yes       Favorable
# 4350                       Yes  Very favorable
# 74557  No, and I don't plan to             NaN
# 51706                      Yes     Indifferent
# 8983                       Yes       Favorable
# 88949  No, and I don't plan to             NaN
# 83554                      Yes  Very favorable
# 10730                      Yes       Favorable
#
#                                                    AIAcc  \
# 67793                             Other (please explain)
# 59005                                                NaN
# 53787            Increase productivity;Speed up learning
# 4350             Increase productivity;Speed up learning
# 74557                                                NaN
# 51706                              Increase productivity
# 8983                                   Speed up learning
# 88949                                                NaN
# 83554  Increase productivity;Greater efficiency;Speed...
# 10730                              Increase productivity
#
#                             AIBen  \
# 67793             Highly distrust
# 59005                         NaN
# 53787             Highly distrust
# 4350   Neither trust nor distrust
# 74557                         NaN
# 51706             Highly distrust
# 8983               Somewhat trust
# 88949                         NaN
# 83554              Somewhat trust
# 10730  Neither trust nor distrust
#
#                                AIToolInterested in Using  \
# 67793                                                NaN
# 59005                                                NaN
# 53787                                   Documenting code
# 4350                                    Project planning
# 74557                                                NaN
# 51706            Debugging and getting help;Testing code
# 8983   Project planning;Debugging and getting help;Te...
# 88949                                                NaN
# 83554  Project planning;Documenting code;Testing code...
# 10730                                                NaN
#
#                                    AIToolCurrently Using  \
# 67793                                                NaN
# 59005                                                NaN
# 53787            Writing code;Debugging and getting help
# 4350   Writing code;Documenting code;Debugging and ge...
# 74557                                                NaN
# 51706                                       Writing code
# 8983   Learning about a codebase;Writing code;Documen...
# 88949                                                NaN
# 83554  Learning about a codebase;Writing code;Debuggi...
# 10730  Learning about a codebase;Project planning;Wri...
#
#                            AIToolNot interested in Using  \
# 67793                                                NaN
# 59005                                                NaN
# 53787                                                NaN
# 4350                                                 NaN
# 74557                                                NaN
# 51706  Learning about a codebase;Project planning;Doc...
# 8983   Deployment and monitoring;Collaborating with t...
# 88949                                                NaN
# 83554                                                NaN
# 10730                                                NaN
#
#                                     AINextVery different  \
# 67793                                                NaN
# 59005                                                NaN
# 53787                                                NaN
# 4350                                                 NaN
# 74557                                                NaN
# 51706                                                NaN
# 8983                                                 NaN
# 88949                                                NaN
# 83554                                                NaN
# 10730  Learning about a codebase;Project planning;Wri...
#
#       AINextNeither different nor similar AINextSomewhat similar  \
# 67793                                 NaN                    NaN
# 59005                                 NaN                    NaN
# 53787                                 NaN                    NaN
# 4350                                  NaN                    NaN
# 74557                                 NaN                    NaN
# 51706                                 NaN                    NaN
# 8983                                  NaN                    NaN
# 88949                                 NaN                    NaN
# 83554                                 NaN                    NaN
# 10730                                 NaN                    NaN
#
#                             AINextVery similar  \
# 67793                                      NaN
# 59005                                      NaN
# 53787  Writing code;Debugging and getting help
# 4350                                       NaN
# 74557                                      NaN
# 51706                                      NaN
# 8983                                       NaN
# 88949                                      NaN
# 83554                                      NaN
# 10730                                      NaN
#
#                                 AINextSomewhat different TBranch  \
# 67793                                                NaN     NaN
# 59005                                                NaN      No
# 53787                                                NaN     Yes
# 4350                                                 NaN     NaN
# 74557                                                NaN     NaN
# 51706                                       Writing code     NaN
# 8983   Learning about a codebase;Writing code;Documen...     NaN
# 88949                                                NaN     NaN
# 83554  Learning about a codebase;Writing code;Debuggi...     Yes
# 10730                                                NaN     Yes
#
#                        ICorPM  WorkExp                 Knowledge_1  \
# 67793                     NaN      NaN                         NaN
# 59005                     NaN      NaN                         NaN
# 53787  Individual contributor     20.0              Strongly agree
# 4350                      NaN      NaN                         NaN
# 74557                     NaN      NaN                         NaN
# 51706                     NaN      NaN                         NaN
# 8983                      NaN      NaN                         NaN
# 88949                     NaN      NaN                         NaN
# 83554  Individual contributor      4.0              Strongly agree
# 10730  Individual contributor      3.0  Neither agree nor disagree
#
#                       Knowledge_2                 Knowledge_3  \
# 67793                         NaN                         NaN
# 59005                         NaN                         NaN
# 53787              Strongly agree              Strongly agree
# 4350                          NaN                         NaN
# 74557                         NaN                         NaN
# 51706                         NaN                         NaN
# 8983                          NaN                         NaN
# 88949                         NaN                         NaN
# 83554           Strongly disagree              Strongly agree
# 10730  Neither agree nor disagree  Neither agree nor disagree
#
#                       Knowledge_4                 Knowledge_5  \
# 67793                         NaN                         NaN
# 59005                         NaN                         NaN
# 53787              Strongly agree              Strongly agree
# 4350                          NaN                         NaN
# 74557                         NaN                         NaN
# 51706                         NaN                         NaN
# 8983                          NaN                         NaN
# 88949                         NaN                         NaN
# 83554              Strongly agree              Strongly agree
# 10730  Neither agree nor disagree  Neither agree nor disagree
#
#                       Knowledge_6                 Knowledge_7  \
# 67793                         NaN                         NaN
# 59005                         NaN                         NaN
# 53787              Strongly agree              Strongly agree
# 4350                          NaN                         NaN
# 74557                         NaN                         NaN
# 51706                         NaN                         NaN
# 8983                          NaN                         NaN
# 88949                         NaN                         NaN
# 83554           Strongly disagree           Strongly disagree
# 10730  Neither agree nor disagree  Neither agree nor disagree
#
#                       Knowledge_8        Frequency_1        Frequency_2  \
# 67793                         NaN                NaN                NaN
# 59005                         NaN                NaN                NaN
# 53787              Strongly agree  6-10 times a week  6-10 times a week
# 4350                          NaN                NaN                NaN
# 74557                         NaN                NaN                NaN
# 51706                         NaN                NaN                NaN
# 8983                          NaN                NaN                NaN
# 88949                         NaN                NaN                NaN
# 83554              Strongly agree   1-2 times a week   1-2 times a week
# 10730  Neither agree nor disagree   1-2 times a week   1-2 times a week
#
#             Frequency_3               TimeSearching  \
# 67793               NaN                         NaN
# 59005               NaN                         NaN
# 53787  1-2 times a week      Over 120 minutes a day
# 4350                NaN                         NaN
# 74557               NaN                         NaN
# 51706               NaN                         NaN
# 8983                NaN                         NaN
# 88949               NaN                         NaN
# 83554             Never      Over 120 minutes a day
# 10730  1-2 times a week  Less than 15 minutes a day
#
#                     TimeAnswering  \
# 67793                         NaN
# 59005                         NaN
# 53787      Over 120 minutes a day
# 4350                          NaN
# 74557                         NaN
# 51706                         NaN
# 8983                          NaN
# 88949                         NaN
# 83554  Less than 15 minutes a day
# 10730         15-30 minutes a day
#
#                                         ProfessionalTech  \
# 67793                                                NaN
# 59005                                                NaN
# 53787  DevOps function;Microservices;Automated testin...
# 4350                                                 NaN
# 74557                                                NaN
# 51706                                                NaN
# 8983                                                 NaN
# 88949                                                NaN
# 83554  Continuous integration (CI) and (more often) c...
# 10730                                      None of these
#
#                                                 Industry  \
# 67793                                                NaN
# 59005                                                NaN
# 53787  Information Services, IT, Software Development...
# 4350                                                 NaN
# 74557                                                NaN
# 51706                                                NaN
# 8983                                                 NaN
# 88949                                                NaN
# 83554  Information Services, IT, Software Development...
# 10730                                                NaN
#
#                 SurveyLength                  SurveyEase  ConvertedCompYearly
# 67793               Too long                   Difficult                  NaN
# 59005               Too long                   Difficult                  NaN
# 53787               Too long  Neither easy nor difficult                  NaN
# 4350                Too long                        Easy                  NaN
# 74557               Too long                        Easy                  NaN
# 51706              Too short                        Easy                  NaN
# 8983                Too long  Neither easy nor difficult                  NaN
# 88949  Appropriate in length  Neither easy nor difficult                  NaN
# 83554  Appropriate in length                        Easy                  NaN
# 10730  Appropriate in length  Neither easy nor difficult                  NaN

# %%
import pandas as pd
import numpy as np

# %%
people = {
    'first': ['Corey', 'Jane', 'John', 'Chris', np.nan, None, 'NA'], 
    'last': ['Schafer', 'Doe', 'Doe', 'Schafer', np.nan, np.nan, 'Missing'], 
    'email': ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com', None, np.nan, 'Anonymous@email.com', 'NA'],
    'age': ['33', '55', '63', '36', None, None, 'Missing']
}

# %%
df = pd.DataFrame(people)
df
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                      NaN       36
# 4    NaN      NaN                      NaN      NaN
# 5    NaN      NaN      Anonymous@email.com      NaN
# 6     NA  Missing                       NA  Missing

# %%
# for removing the missing values from the dataframe we have - 'Nan' , 'Missing' 
df.replace('NA',np.nan,inplace=True)
df.replace('Missing',np.nan,inplace=True)
# Out:
#    first     last                    email  age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com   33
# 1   Jane      Doe        JaneDoe@email.com   55
# 2   John      Doe        JohnDoe@email.com   63
# 3  Chris  Schafer                      NaN   36
# 4    NaN      NaN                      NaN  NaN
# 5    NaN      NaN      Anonymous@email.com  NaN
# 6    NaN      NaN                      NaN  NaN

# %%
# df.dropna(axis='index',how='any',subset=['last','email'])
# df.dropna(axis='columns',how='any',subset=['last','email']) # axis = index will work on rows, columns - will work on columns

df.dropna(axis='index',how='all',subset=['last','email'])
# Out:
#    first     last                    email  age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com   33
# 1   Jane      Doe        JaneDoe@email.com   55
# 2   John      Doe        JohnDoe@email.com   63
# 3  Chris  Schafer                      NaN   36
# 5    NaN      NaN      Anonymous@email.com  NaN

# %%
df.isna()
# it will provide the mask wheather the value is na or not - give true or false based on condition
# Out:
#    first   last  email    age
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False   True  False
# 4   True   True   True   True
# 5   True   True  False   True
# 6   True   True   True   True

# %%
df.fillna('0',inplace=True)
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@email.com  55
# 2   John      Doe        JohnDoe@email.com  63
# 3  Chris  Schafer                        0  36
# 4      0        0                        0   0
# 5      0        0      Anonymous@email.com   0
# 6      0        0                        0   0

# %%
df
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@email.com  55
# 2   John      Doe        JohnDoe@email.com  63
# 3  Chris  Schafer                        0  36
# 4      0        0                        0   0
# 5      0        0      Anonymous@email.com   0
# 6      0        0                        0   0

# %%
df.dtypes
# Out:
# first    str
# last     str
# email    str
# age      str
# dtype: object

# %%
type(np.nan)
# Out:
# float

# %%
df['age'] = df['age'].astype(float) # type cast the value

# %%
df.dtypes
# Out:
# first        str
# last         str
# email        str
# age      float64
# dtype: object

# %%
df['age'].mean()
# Out:
# np.float64(26.714285714285715)

# %%
# df.astype() - to convert the Whole dataframe into one datatype as required

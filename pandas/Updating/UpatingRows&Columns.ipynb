# %%
people = {
    "first": ["Corey", 'Jane', 'John'], 
    "last": ["Schafer", 'Doe', 'Doe'], 
    "email": ["CoreyMSchafer@gmail.com", 'JaneDoe@email.com', 'JohnDoe@email.com']
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='str')

# %%
df.columns = ['first_name','last_name','email']

# %%
df.columns
# Out:
# Index(['first_name', 'last_name', 'email'], dtype='str')

# %%
df
# Out:
#   first_name last_name                    email
# 0      Corey   Schafer  CoreyMSchafer@gmail.com
# 1       Jane       Doe        JaneDoe@email.com
# 2       John       Doe        JohnDoe@email.com

# %%
df.columns = [x.lower() for x in df.columns]
df
# Out:
#   first_name last_name                    email
# 0      Corey   Schafer  CoreyMSchafer@gmail.com
# 1       Jane       Doe        JaneDoe@email.com
# 2       John       Doe        JohnDoe@email.com

# %%
df.columns = df.columns.str.replace(' ','_')
df
# Out:
#   first_name last_name                    email
# 0      Corey   Schafer  CoreyMSchafer@gmail.com
# 1       Jane       Doe        JaneDoe@email.com
# 2       John       Doe        JohnDoe@email.com

# %%
df.rename(columns={'first_name':'first','last_name':'last'})
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df
# Out:
#   first_name last_name                    email
# 0      Corey   Schafer  CoreyMSchafer@gmail.com
# 1       Jane       Doe        JaneDoe@email.com
# 2       John       Doe        JohnDoe@email.com

# %%
# if we want to keep the changes we need to put inplace true

# %%
df.rename(columns={'first_name':'first','last_name':'last'},inplace = True)

# %%
df # changes are visisble
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df.loc[2]
# Out:
# first                 John
# last                   Doe
# email    JohnDoe@email.com
# Name: 2, dtype: str

# %%
df.loc[2] = ['John','Smith','JohnSmith@email.com']

# %%
df # updated row
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John    Smith      JohnSmith@email.com

# %%
 df.loc[2,['last','email']] = ['Doe','JohnDoe@email.com']

# %%
df.loc[2,'last'] = 'Smith'

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John    Smith        JohnDoe@email.com

# %%
df.at[2,'last'] = 'Doe'

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John    Smith        JohnDoe@email.com

# %%
filt = (df['email'] == 'JohnDoe@email.com')
df[filt]['last'] = 'Smith'
# Out:
# C:\Users\bharat singh thakur\AppData\Local\Temp\ipykernel_5020\1842663546.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   df[filt]['last'] = 'Smith'

# %%
filt = (df['email'] == 'JohnDoe@email.com')
df.loc[filt,'last'] = 'Smith'

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John    Smith        JohnDoe@email.com

# %%
df['email'].str.lower()
# Out:
# 0    coreymschafer@gmail.com
# 1          janedoe@email.com
# 2          johndoe@email.com
# Name: email, dtype: str

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John    Smith        JohnDoe@email.com

# %%
# make the changes visible 
# it will be for all the rows at once 
df['email'] = df['email'].str.lower()

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  coreymschafer@gmail.com
# 1   Jane      Doe        janedoe@email.com
# 2   John    Smith        johndoe@email.com

# %%
# changes for single row

# %%
# we have four methods 
# apply #map #applymap #replace

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John    Smith        JohnDoe@email.com

# %%
# apply methods - work with dataframe and series object 
# -- for series object 
df['email'].apply(len)
# Out:
# 0    23
# 1    17
# 2    17
# Name: email, dtype: int64

# %%
def update_email(email):
    return email.upper()

# %%
df['email'].apply(update_email) # to assign the value to the series
# Out:
# 0    COREYMSCHAFER@GMAIL.COM
# 1          JANEDOE@EMAIL.COM
# 2          JOHNDOE@EMAIL.COM
# Name: email, dtype: str

# %%
df['email'] = df['email'].apply(update_email) # updating series email

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  COREYMSCHAFER@GMAIL.COM
# 1   Jane      Doe        JANEDOE@EMAIL.COM
# 2   John    Smith        JOHNDOE@EMAIL.COM

# %%
df['email'] = df['email'].apply(lambda x: x.lower()) # using anonymous function for apply

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  coreymschafer@gmail.com
# 1   Jane      Doe        janedoe@email.com
# 2   John    Smith        johndoe@email.com

# %%
df.apply(len) # It is applying to every column of the series of that df
# Out:
# first    3
# last     3
# email    3
# dtype: int64

# %%
len(df['email']) # same result for the dataframe column as well
# Out:
# 3

# %%
# we can apply min function in series of , "IT will give the value accordingly"
df.apply(pd.Series.min)
# Out:
# first                      Corey
# last                         Doe
# email    coreymschafer@gmail.com
# dtype: str

# %%
# applyMap - apply a function to every indivisual dataframe it only works with dataframe

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  coreymschafer@gmail.com
# 1   Jane      Doe        janedoe@email.com
# 2   John    Smith        johndoe@email.com

# %%
df.applymap(lambda x: x.len(str(x)))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 df.applymap(lambda x: x.len(str(x)))
#
# File c:\Users\bharat singh thakur\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'applymap'

# %%
# we have another method called 
# map 
# map is used for subsituting each value in a series with another value

# %%
df['first']
# Out:
# 0    Corey
# 1     Jane
# 2     John
# Name: first, dtype: str

# %%
df['first'].map({'Corey':'Bharat','Jane':'Niko'}) # it will keep nan values in series
# Out:
# 0    Bharat
# 1      Niko
# 2       NaN
# Name: first, dtype: str

# %%
df['first'] = df['first'].replace({'Corey':'Bharat','Jane':'Niko'}) # replace will keep the john value

# %%
df
# Out:
#     first     last                    email
# 0  Bharat  Schafer  coreymschafer@gmail.com
# 1    Niko      Doe        janedoe@email.com
# 2    John    Smith        johndoe@email.com

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined
